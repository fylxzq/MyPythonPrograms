# %% [markdown]
# # 球员分析

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
play_data = pd.read_csv('inputData/player_data.csv')

# %%
play_data.head()
# Out:
#   player_name season race_rst        rival rate_shot  rebounds  assists  \
# 0     勒布朗-詹姆斯  03-04        负   国王106-92骑士     60.0%         6        9
# 1     勒布朗-詹姆斯  03-04        负    太阳95-86骑士     47.1%        12        8
# 2     勒布朗-詹姆斯  03-04        负  开拓者104-85骑士     25.0%         4        6
# 3     勒布朗-詹姆斯  03-04        负    掘金93-89骑士     27.3%        11        7
# 4     勒布朗-詹姆斯  03-04        负   步行者91-90骑士     44.4%         5        3
#
#    steals  caps  scores
# 0       4     0      25
# 1       1     0      21
# 2       2     0       8
# 3       2     3       7
# 4       0     0      23

# %%
play_data.describe()
# Out:
#           rebounds      assists       steals         caps       scores
# count  1192.000000  1192.000000  1192.000000  1192.000000  1192.000000
# mean      7.416107     7.214765     1.620805     0.770134    27.161913
# std       3.012375     2.916846     1.303165     0.915863     7.889016
# min       0.000000     0.000000     0.000000     0.000000     3.000000
# 25%       5.000000     5.000000     1.000000     0.000000    22.000000
# 50%       7.000000     7.000000     1.000000     1.000000    27.000000
# 75%       9.000000     9.000000     2.000000     1.000000    32.000000
# max      19.000000    19.000000     7.000000     5.000000    61.000000

# %%
play_data['rate_shot'] = play_data['rate_shot'].str.strip('%').astype(float) /100 #将百分号去掉转化为float类型

# %%
play_data.describe()
# Out:
#          rate_shot     rebounds      assists       steals         caps  \
# count  1192.000000  1192.000000  1192.000000  1192.000000  1192.000000
# mean      0.506038     7.416107     7.214765     1.620805     0.770134
# std       0.113290     3.012375     2.916846     1.303165     0.915863
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.435000     5.000000     5.000000     1.000000     0.000000
# 50%       0.500000     7.000000     7.000000     1.000000     1.000000
# 75%       0.579000     9.000000     9.000000     2.000000     1.000000
# max       0.929000    19.000000    19.000000     7.000000     5.000000
#
#             scores
# count  1192.000000
# mean     27.161913
# std       7.889016
# min       3.000000
# 25%      22.000000
# 50%      27.000000
# 75%      32.000000
# max      61.000000

# %%
play_data['rival'] = play_data['rival'].str.extract('(\d{0,2}.*?)\d')#使用series对象的str对象正则提取rival列的对手

# %%
play_data.head()
# Out:
#   player_name season race_rst rival  rate_shot  rebounds  assists  steals  \
# 0     勒布朗-詹姆斯  03-04        负    国王      0.600         6        9       4
# 1     勒布朗-詹姆斯  03-04        负    太阳      0.471        12        8       1
# 2     勒布朗-詹姆斯  03-04        负   开拓者      0.250         4        6       2
# 3     勒布朗-詹姆斯  03-04        负    掘金      0.273        11        7       2
# 4     勒布朗-詹姆斯  03-04        负   步行者      0.444         5        3       0
#
#    caps  scores
# 0     0      25
# 1     0      21
# 2     0       8
# 3     3       7
# 4     0      23

# %%
play_data['race_rst'] = play_data['race_rst'].replace(['负'],0)
play_data['race_rst'] = play_data['race_rst'].replace(['胜'],1)#胜为1，负为0

# %%
play_data.head()
# Out:
#   player_name season  race_rst rival  rate_shot  rebounds  assists  steals  \
# 0     勒布朗-詹姆斯  03-04         0    国王      0.600         6        9       4
# 1     勒布朗-詹姆斯  03-04         0    太阳      0.471        12        8       1
# 2     勒布朗-詹姆斯  03-04         0   开拓者      0.250         4        6       2
# 3     勒布朗-詹姆斯  03-04         0    掘金      0.273        11        7       2
# 4     勒布朗-詹姆斯  03-04         0   步行者      0.444         5        3       0
#
#    caps  scores
# 0     0      25
# 1     0      21
# 2     0       8
# 3     3       7
# 4     0      23

# %%
play_data.groupby('rival').sum().iloc[1:,2:].sort_values('scores',ascending=False).head()
# Out:
#        rebounds  assists  steals  caps  scores
# rival
# 雄鹿          413      391      83    39    1604
# 公牛          417      364      98    47    1603
# 步行者         428      369      97    52    1534
# 老鹰          444      395      99    38    1507
# 凯尔特         369      357      88    54    1493

# %%
play_data.sort_values('scores',ascending=False).head(10)#球员生涯最高得分排名
# Out:
#      player_name season  race_rst rival rate_shot  rebounds  assists  steals  \
# 819      勒布朗-詹姆斯  13-14         1    山猫     66.7%         7        4       0
# 1069     勒布朗-詹姆斯  17-18         1    奇才     67.6%        11        7       3
# 140      勒布朗-詹姆斯  04-05         0    猛龙     50.0%        10        5       2
# 443      勒布朗-詹姆斯  08-09         1    雄鹿     55.2%         5        9       0
# 438      勒布朗-詹姆斯  08-09         1   尼克斯     51.5%         9       11       0
# 177      勒布朗-詹姆斯  05-06         0    雄鹿     65.5%         7        7       2
# 594      勒布朗-詹姆斯  10-11         1    魔术     68.0%        11        8       1
# 455      勒布朗-詹姆斯  08-09         1    国王     53.3%         4        9       2
# 1158     勒布朗-詹姆斯  18-19         1    热火     61.3%         8        3       2
# 348      勒布朗-詹姆斯  07-08         1    灰熊     64.3%         8        9       3
#
#       caps  scores
# 819      0      61
# 1069     2      57
# 140      0      56
# 443      0      55
# 438      2      52
# 177      0      52
# 594      1      51
# 455      3      51
# 1158     1      51
# 348      1      51

# %%
play_data.head()
# Out:
#   player_name season  race_rst rival  rate_shot  rebounds  assists  steals  \
# 0     勒布朗-詹姆斯  03-04         0    国王      0.600         6        9       4
# 1     勒布朗-詹姆斯  03-04         0    太阳      0.471        12        8       1
# 2     勒布朗-詹姆斯  03-04         0   开拓者      0.250         4        6       2
# 3     勒布朗-詹姆斯  03-04         0    掘金      0.273        11        7       2
# 4     勒布朗-詹姆斯  03-04         0   步行者      0.444         5        3       0
#
#    caps  scores
# 0     0      25
# 1     0      21
# 2     0       8
# 3     3       7
# 4     0      23

# %%
play_data.groupby('rival').mean().iloc[1:,0:1].sort_values('race_rst').head(10)#球员职业生涯对战球队最低胜率排名
# Out:
#        race_rst
# rival
# 火箭     0.433333
# 马刺     0.451613
# 掘金     0.451613
# 超音速    0.500000
# 公牛     0.535714
# 勇士     0.535714
# 鹈鹕     0.538462
# 小牛     0.576923
# 热火     0.578947
# 凯尔特    0.588235

# %% [markdown]
# # 机器学习数据分析

# %%
import pandas as pd
import numpy as np
import time

# %%
team_data = pd.read_csv('inputData/team_data1.csv')
team_data.tail()
# Out:
#      year team_name  wins  loss win_rates  coach_off_times  coach_wins_rate  \
# 932  2017     洛杉矶湖人    35    47     42.7%                0             39.5
# 933  2017   萨克拉门托国王    27    55     32.9%                3             50.0
# 934  2017    达拉斯独行侠    24    58     29.3%               12             54.7
# 935  2017     孟菲斯灰熊    22    60     26.8%                1             37.1
# 936  2017    菲尼克斯太阳    21    61     25.6%                0             28.0
#
#      coach_champions
# 932                0
# 933                0
# 934                1
# 935                0
# 936                0

# %%
team_data.rename(columns={'year':'season'},inplace=True)#将yaer列名字改成season列，方便后面的连接操作

# %%
teams = ['马刺', '小牛', '太阳', '勇士', '骑士', '爵士', '掘金', '开拓者', '快船', '篮网', '超音速',
       '公牛', '火箭', '活塞', '尼克斯', '雄鹿', '子弹', '国王', '步行者', '凯尔特', '76人',
       '老鹰', '热火', '黄蜂', '魔术', '森林狼', '灰熊', '猛龙', '奇才', '山猫', '雷霆', '鹈鹕',
       '独行侠','湖人']

# %%
#次函数得到team_data里队伍的对名，去掉前面的地名
def get_team(x):
    for i in teams:
        if(i in x):
            return i

# %%
team_data['rival'] = team_data['team_name'].apply(get_team)
team_data.drop('team_name',axis=1,inplace=True)

# %%
lakes_info = team_data.loc[team_data['rival']=="湖人"]

# %%
team_data= team_data.loc[team_data['rival']!='湖人']#去除湖人队，因为我们需要预测湖人的比赛结果，对手不可能是湖人队
team_data['wins-loss'] = team_data['wins'] - team_data['loss']
team_data['win_rates'] = team_data['win_rates'].str.strip('%').astype(float) /100 #将百分号去掉转化为float类型
team_data.head()
# Out:
#    season  wins  loss  win_rates  coach_off_times  coach_wins_rate  \
# 0    1985    67    15      0.817                9             67.4
# 1    1985    57    25      0.695               18             55.7
# 2    1985    54    28      0.659                2             43.0
# 3    1985    50    32      0.610               11             54.9
# 4    1985    46    36      0.561               12             59.3
#
#    coach_champions rival  wins-loss
# 0                2   凯尔特         52
# 1                0    雄鹿         32
# 2                0   76人         26
# 3                0    老鹰         18
# 4                2    活塞         10

# %%
lake_data = pd.read_csv('inputData/days.csv')
lake_data = lake_data.iloc[:,1:]
lake_data.head()
# Out:
#   team_name   game_time game_rst host_guest        rival shot_rate  rebounds  \
# 0     洛杉矶湖人  1985-10-26        胜          客  马刺116-121湖人     49.5%        53
# 1     洛杉矶湖人  1985-10-29        胜          客  小牛115-133湖人     57.4%        60
# 2     洛杉矶湖人  1985-10-31        胜          客  太阳107-144湖人     59.1%        50
# 3     洛杉矶湖人  1985-11-02        胜          客  勇士116-120湖人     58.3%        36
# 4     洛杉矶湖人  1985-11-05        负          主  骑士129-111湖人     42.2%        43
#
#    assists  scores  season  game_time1  days
# 0       30     121    1985  1985-10-25     1
# 1       35     133    1985  1985-10-26     3
# 2       42     144    1985  1985-10-29     2
# 3       25     120    1985  1985-10-31     2
# 4       26     111    1985  1985-11-02     3

# %%
# tmp_data = list([i for i in np.array(lake_data.game_time)[:-1]])
# tmp_data.insert(0,'1985-10-25')
# lake_data['game_time1'] = tmp_data
# lake_data['game_time'] = pd.to_datetime(lake_data['game_time'])
# lake_data['game_time1'] = pd.to_datetime(lake_data['game_time1'])
# lake_data['days'] = lake_data['game_time'] - lake_data['game_time1']
# lake_data.to_csv('inputData/days.csv')这段代码是为了求出比赛相隔的天数，生产一个新的文件，在去处理文件，重新读取即可

# %%
#此函数求出湖人队每场的比赛所在的赛季，也是用于连接
def get_season(game_time):
    ymd_lst = game_time.split('-')
    year = ymd_lst[0]
    month = int(ymd_lst[1])
    day = ymd_lst[2]
    if(month>9):
        return int(year)
    else:
        return int(year) -1

# %%
lake_data['season'] = lake_data['game_time'].apply(get_season)

# %%
lake_data.tail()
# Out:
#      team_name   game_time game_rst host_guest         rival shot_rate  \
# 2721     洛杉矶湖人  2019-03-04        负          主   快船113-105湖人     41.8%
# 2722     洛杉矶湖人  2019-03-06        负          主    掘金115-99湖人     47.6%
# 2723     洛杉矶湖人  2019-03-09        负          主  凯尔特120-107湖人     48.4%
# 2724     洛杉矶湖人  2019-03-12        胜          客   公牛107-123湖人     54.7%
# 2725     洛杉矶湖人  2019-03-14        负          客    猛龙111-98湖人     44.7%
#
#       rebounds  assists  scores  season  game_time1  days
# 2721        40       22     105    2018  2019-03-02     2
# 2722        41       26      99    2018  2019-03-04     2
# 2723        43       28     107    2018  2019-03-06     3
# 2724        41       23     123    2018  2019-03-09     3
# 2725        46       24      98    2018  2019-03-12     2

# %%
lake_data['rival'] = lake_data['rival'].str.extract('(\d{0,2}.*?)\d')#正则提取湖人的对手

# %%
lake_data.head()
# Out:
#   team_name   game_time game_rst host_guest rival shot_rate  rebounds  \
# 0     洛杉矶湖人  1985-10-26        胜          客    马刺     49.5%        53
# 1     洛杉矶湖人  1985-10-29        胜          客    小牛     57.4%        60
# 2     洛杉矶湖人  1985-10-31        胜          客    太阳     59.1%        50
# 3     洛杉矶湖人  1985-11-02        胜          客    勇士     58.3%        36
# 4     洛杉矶湖人  1985-11-05        负          主    骑士     42.2%        43
#
#    assists  scores  season  game_time1  days
# 0       30     121    1985  1985-10-25     1
# 1       35     133    1985  1985-10-26     3
# 2       42     144    1985  1985-10-29     2
# 3       25     120    1985  1985-10-31     2
# 4       26     111    1985  1985-11-02     3

# %%
lake_data['game_month'] = lake_data['game_time'].str.extract('-(.*?)-')

# %%
lake_data.head()
# Out:
#   team_name   game_time game_rst host_guest rival shot_rate  rebounds  \
# 0     洛杉矶湖人  1985-10-26        胜          客    马刺     49.5%        53
# 1     洛杉矶湖人  1985-10-29        胜          客    小牛     57.4%        60
# 2     洛杉矶湖人  1985-10-31        胜          客    太阳     59.1%        50
# 3     洛杉矶湖人  1985-11-02        胜          客    勇士     58.3%        36
# 4     洛杉矶湖人  1985-11-05        负          主    骑士     42.2%        43
#
#    assists  scores  season  game_time1  days game_month
# 0       30     121    1985  1985-10-25     1         10
# 1       35     133    1985  1985-10-26     3         10
# 2       42     144    1985  1985-10-29     2         10
# 3       25     120    1985  1985-10-31     2         11
# 4       26     111    1985  1985-11-02     3         11

# %%
lake_data = lake_data.loc[lake_data['rival']!=' ']
lake_data.head()
# Out:
#   team_name   game_time game_rst host_guest rival shot_rate  rebounds  \
# 0     洛杉矶湖人  1985-10-26        胜          客    马刺     49.5%        53
# 1     洛杉矶湖人  1985-10-29        胜          客    小牛     57.4%        60
# 2     洛杉矶湖人  1985-10-31        胜          客    太阳     59.1%        50
# 3     洛杉矶湖人  1985-11-02        胜          客    勇士     58.3%        36
# 4     洛杉矶湖人  1985-11-05        负          主    骑士     42.2%        43
#
#    assists  scores  season  game_time1  days game_month
# 0       30     121    1985  1985-10-25     1         10
# 1       35     133    1985  1985-10-26     3         10
# 2       42     144    1985  1985-10-29     2         10
# 3       25     120    1985  1985-10-31     2         11
# 4       26     111    1985  1985-11-02     3         11

# %%
lake_data = lake_data.loc[lake_data['season']!=2018]
lake_data.tail()
# Out:
#      team_name   game_time game_rst host_guest rival shot_rate  rebounds  \
# 2653     洛杉矶湖人  2018-04-04        胜          主    马刺     54.7%        44
# 2654     洛杉矶湖人  2018-04-06        负          主   森林狼     39.2%        53
# 2655     洛杉矶湖人  2018-04-08        负          主    爵士     39.8%        44
# 2656     洛杉矶湖人  2018-04-10        负          主    火箭     42.2%        47
# 2657     洛杉矶湖人  2018-04-11        胜          客    快船     47.7%        49
#
#       assists  scores  season  game_time1  days game_month
# 2653       32     122    2017  2018-04-03     1         04
# 2654       16      96    2017  2018-04-04     2         04
# 2655       20      97    2017  2018-04-06     2         04
# 2656       22      99    2017  2018-04-08     2         04
# 2657       25     115    2017  2018-04-10     1         04

# %%
detail_info = pd.merge(team_data,lake_data,on=['rival','season'])

# %%
detail_info.to_csv('inputData/details.csv',index=False)

# %% [markdown]
# # 可视化数据

# %%
import pandas as pd
import matplotlib.pyplot as plt
play_data = pd.read_csv('inputData/player_data.csv')
play_data['rival'] = play_data['rival'].str.extract('(\d{0,2}.*?)\d')

# %%
total_score = play_data.groupby('rival').sum().iloc[1:,2:].sort_values('scores',ascending=False)

# %%
play_data['race_rst'] = play_data['race_rst'].replace(['负'],0)
play_data['race_rst'] = play_data['race_rst'].replace(['胜'],1)#胜为1，负为0

# %%
low_rate_team = play_data.groupby('rival').mean().iloc[1:,0:1].sort_values('race_rst').reset_index().head(5)
high_rate_team =  play_data.groupby('rival').mean().iloc[1:,0:1].sort_values('race_rst',ascending=False).reset_index().head(5)

# %%
high_rate_team
# Out:
#   rival  race_rst
# 0   独行侠  1.000000
# 1    骑士  0.928571
# 2    山猫  0.857143
# 3    黄蜂  0.800000
# 4   76人  0.795455

# %%
scores_rank = play_data.sort_values('scores',ascending=False).head(10)

# %%
# Out:
#      player_name season  race_rst rival rate_shot  rebounds  assists  steals  \
# 819      勒布朗-詹姆斯  13-14         1    山猫     66.7%         7        4       0
# 1069     勒布朗-詹姆斯  17-18         1    奇才     67.6%        11        7       3
# 140      勒布朗-詹姆斯  04-05         0    猛龙     50.0%        10        5       2
# 443      勒布朗-詹姆斯  08-09         1    雄鹿     55.2%         5        9       0
# 438      勒布朗-詹姆斯  08-09         1   尼克斯     51.5%         9       11       0
# 177      勒布朗-詹姆斯  05-06         0    雄鹿     65.5%         7        7       2
# 594      勒布朗-詹姆斯  10-11         1    魔术     68.0%        11        8       1
# 455      勒布朗-詹姆斯  08-09         1    国王     53.3%         4        9       2
# 1158     勒布朗-詹姆斯  18-19         1    热火     61.3%         8        3       2
# 348      勒布朗-詹姆斯  07-08         1    灰熊     64.3%         8        9       3
#
#       caps  scores
# 819      0      61
# 1069     2      57
# 140      0      56
# 443      0      55
# 438      2      52
# 177      0      52
# 594      1      51
# 455      3      51
# 1158     1      51
# 348      1      51

# %%
import numpy as np
plt.rcParams['font.sans-serif']=['SimHei']

# %%
x = scores_rank['rival']
y = scores_rank['scores']
plt.style.use("ggplot")
fig,ax = plt.subplots(figsize=(10,6),dpi=80)
ax.barh(np.arange(len(x)),y,color=['r'],tick_label=x)
for a,b in zip(np.arange(len(x)),y):
    ax.text(b+3,a-0.2,b,ha="center",fontsize=20,color='b')

# %%
x1 = low_rate_team['rival']
y1 = low_rate_team['race_rst']
plt.style.use("ggplot")
fig= plt.figure(figsize=(14,8),dpi=80)
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax1.bar(np.arange(len(x)),y1,tick_label=x1,color=['r'])
ax1.set_title('职业生涯对战球队最低胜率前五名')
for a,b in zip(np.arange(len(x)),y):
    ax1.text(a,b+0.01,str(round(b,2)*100)+'%',ha="center",fontsize=20,color='red')
    
x2 = high_rate_team['rival']
y2= high_rate_team['race_rst']
ax2.bar(np.arange(len(x)),y2,tick_label=x2,color=['g'])
ax2.set_title('职业生涯对战球队最高胜率前五名')
for a,b in zip(np.arange(len(x)),y2):
    ax2.text(a,b+0.01,str(round(b,2)*100)+'%',ha="center",fontsize=20,color='red')

# %%
play_data.groupby('rival').sum().iloc[1:,2:].sort_values('scores',ascending=False).to_csv('rst.csv')

# %%
team_loc = pd.read_csv('team1.csv')

# %%
team_loc.iloc[:,4:6].groupby('state').sum().sort_values('scores',ascending=False).to_csv('team2.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
players_career_data = pd.read_csv('inputData/players_career_data.csv')

# %%
players_career_data.head(5)
# Out:
#   chinese_name   english_name  points  assists  rebounds  steals  shot_rate  \
# 0      勒布朗-詹姆斯   LeBron James    27.2      7.2       7.4     1.6       50.4
# 1       斯蒂芬-库里  Stephen Curry    23.5      6.6       4.5     1.7       47.7
# 2       詹姆斯-哈登   James Harden    24.2      6.2       5.2     1.6       44.2
# 3      科比-布莱恩特    Kobe Bryant    25.0      4.7       5.2     1.4       44.7
# 4       凯文-杜兰特   Kevin Durant    27.1      4.1       7.1     1.1       49.2
#
#    block
# 0    0.8
# 1    0.2
# 2    0.5
# 3    0.5
# 4    1.1

# %%
max_lst = list(np.array(players_career_data.describe().iloc[7:8,:])[0])

# %%
data = np.array(players_career_data.iloc[4:5,2:])[0]
data =np.array([data[i]/max_lst[i] for i in range(6)])
data
# Out:
# array([0.90033223, 0.36607143, 0.52205882, 0.47826087, 0.73432836,
#        0.35483871])

# %%
plt.rcParams['font.sans-serif']=['SimHei']
#=======自己设置开始============
#标签
labels = ['得分','助攻','篮板','抢断','命中率','盖帽']
#数据个数
dataLenth = 6
#数据



data1 = np.concatenate((data, [data[0]]))
#data2 = np.concatenate((data2, [data2[0]]))
#========自己设置结束============

angles = np.linspace(0, 2*np.pi, dataLenth, endpoint=False)
angles = np.concatenate((angles, [angles[0]])) # 闭合

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, polar=True)# polar参数！！
ax.plot(angles, data1, 'bo-', linewidth=2)# 画线
ax.fill(angles, data1, facecolor='r', alpha=0.25)# 填充
ax.set_thetagrids(angles * 180/np.pi, labels, fontproperties="SimHei")
ax.set_title("杜兰特个人能力雷达图")
ax.set_rgrids(np.arange(0,1.2,0.2),'-')
plt.legend(loc="upper right")
ax.grid(True)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import pandas as pd

# %%
details = pd.read_csv('inputData/details.csv')

# %%
details = details.iloc[:,:]
details.head()
# Out:
#    season  wins  loss  win_rates  coach_off_times  coach_wins_rate  \
# 0    1985    67    15      0.817                9             67.4
# 1    1985    67    15      0.817                9             67.4
# 2    1985    57    25      0.695               18             55.7
# 3    1985    57    25      0.695               18             55.7
# 4    1985    54    28      0.659                2             43.0
#
#    coach_champions rival  wins-loss team_name   game_time game_rst host_guest  \
# 0                2   凯尔特         52     洛杉矶湖人  1986-01-22        负          客
# 1                2   凯尔特         52     洛杉矶湖人  1986-02-16        负          主
# 2                0    雄鹿         32     洛杉矶湖人  1985-12-18        胜          客
# 3                0    雄鹿         32     洛杉矶湖人  1986-01-28        胜          主
# 4                0   76人         26     洛杉矶湖人  1986-01-31        胜          主
#
#   shot_rate  rebounds  assists  scores  game_time1  days  game_month
# 0     38.6%        50       17      95  1986-01-20     2           1
# 1     43.6%        40       27      99  1986-02-14     2           2
# 2     53.8%        48       25     107  1985-12-17     1          12
# 3     63.7%        32       33     125  1986-01-25     3           1
# 4     62.9%        31       33     134  1986-01-30     1           1

# %%
details.drop(['wins','loss','coach_champions','rival','team_name','game_time','shot_rate','rebounds','assists','scores','game_time1',],axis=1,inplace=True).head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-c4afb96f0390> in <module>()
# ----> 1 details.drop(['wins','loss','coach_champions','rival','team_name','game_time','shot_rate','rebounds','assists','scores','game_time1',],axis=1,inplace=True).head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
details.head()
# Out:
#    season  win_rates  coach_off_times  coach_wins_rate  wins-loss game_rst  \
# 0    1985      0.817                9             67.4         52        负
# 1    1985      0.817                9             67.4         52        负
# 2    1985      0.695               18             55.7         32        胜
# 3    1985      0.695               18             55.7         32        胜
# 4    1985      0.659                2             43.0         26        胜
#
#   host_guest  days  game_month
# 0          客     2           1
# 1          主     2           2
# 2          客     1          12
# 3          主     3           1
# 4          主     1           1

# %%
details.columns = ['season','rival_rates','rival_coach_times','rival_coach_rates','rival_wl','rst','host_guest','days','game_month']

# %%
end_info = pd.merge(details,lakes_info,on=['season'])

# %%
end_info.head()
# Out:
#    season  rival_rates  rival_coach_times  rival_coach_rates  rival_wl rst  \
# 0    1985        0.817                  9               67.4        52   负
# 1    1985        0.817                  9               67.4        52   负
# 2    1985        0.695                 18               55.7        32   胜
# 3    1985        0.695                 18               55.7        32   胜
# 4    1985        0.659                  2               43.0        26   胜
#
#   host_guest  days  game_month  wins  loss win_rates  coach_off_times  \
# 0          客     2           1    62    20     75.6%               21
# 1          主     2           2    62    20     75.6%               21
# 2          客     1          12    62    20     75.6%               21
# 3          主     3           1    62    20     75.6%               21
# 4          主     1           1    62    20     75.6%               21
#
#    coach_wins_rate  coach_champions rival
# 0             63.6                5    湖人
# 1             63.6                5    湖人
# 2             63.6                5    湖人
# 3             63.6                5    湖人
# 4             63.6                5    湖人

# %%
end_info['win_rates'] = end_info['win_rates'].map(lambda x:x[:-1]).astype(float) / 100

# %%
end_info.drop(['season','rival'],axis=1,inplace=True)

# %%
end_info = pd.read_csv('inputData/end_info.csv')
end_info.head()
# Out:
#    rival_rates  rival_coach_times  rival_coach_rates  rival_wl rst host_guest  \
# 0        0.817                  9               67.4        52   负          客
# 1        0.817                  9               67.4        52   负          主
# 2        0.695                 18               55.7        32   胜          客
# 3        0.695                 18               55.7        32   胜          主
# 4        0.659                  2               43.0        26   胜          主
#
#    days  game_month  wins  loss  win_rates  coach_off_times  coach_wins_rate  \
# 0     2           1    62    20      0.756               21             63.6
# 1     2           2    62    20      0.756               21             63.6
# 2     1          12    62    20      0.756               21             63.6
# 3     3           1    62    20      0.756               21             63.6
# 4     1           1    62    20      0.756               21             63.6
#
#    coach_champions
# 0                5
# 1                5
# 2                5
# 3                5
# 4                5

# %%
end_info['rst'] = end_info['rst'].replace({'负':0,'胜':1})

# %%
end_info['host_guest'] = end_info['host_guest'].replace({'客':0,'主':1})

# %%
end_info['label'] = end_info['rst']

# %%
end_info.to_csv('inputData/machine_data.csv')
