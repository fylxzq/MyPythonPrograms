# %%
import pandas as pd

# %%
raw_df = pd.read_excel("inputData/stuGradeInfo.xlsx")

# %%
raw_df.drop(np.nan,axis=0,inplace=True)
raw_df.head()
# Out:
#            课程号   课程名    ACH1131101          会计学     \
# 20160759.0       闫胜奎                      80.0
# 20163461.0       时煜翔                      60.0
# 20163474.0         王宇                     77.0
# 20163486.0       郑冬阳                      63.0
# 20163498.0       袁晓萌                      95.0
#
#            ECK1131004          宏观经济学      FAE2221004          中国管理智慧        \
# 20160759.0                       77.0                             95.0
# 20163461.0                       70.0                                   -
# 20163474.0                       78.0                                   -
# 20163486.0                       66.0                                   -
# 20163498.0                       92.0                                   -
#
#            LSM2221010          美国国家安全战略分析            \
# 20160759.0                                 94.0
# 20163461.0                                       -
# 20163474.0                                       -
# ...

# %%
raw_df.columns
# Out:
# Index(['课程号   课程名   ', 'ACH1131101          会计学   ',
#        'ECK1131004          宏观经济学     ', 'FAE2221004          中国管理智慧      ',
#        'LSM2221010          美国国家安全战略分析          ',
#        'MTH1121303          计算机程序设计       ',
#        'MTH1131031          管理信息系统      ',
#        'MTH2113303          计算机程序设计（实验）           ',
#        'SAL2221003          创业基础与案例分析         ',
#        'SMG1131004          概率论与数理统计        ',
#        'ECE2221001          外国经济史     ',
#        'KF0022      Photoshop基础与应用              ', 'KF0066      走遍日本    ',
#        'PTM2221013          网球  ', 'LMD2221011          声乐艺术    ',
#        'LMD2221014          演讲与口才     ', 'PTM2221003          篮球  ',
#        '2014TS013         魅力科学    ', '2014TS074         数学的思维方式与创新          ',
#        'PTM2221006          乒乓球   ', 'SAB2221011          市场调查    ',
#        'SAL2223004          创新实践活动      ', 'FLM2221013          法语  ',
#        'LMM2221004          言语交际学     ', 'PTM2221009          太极拳   ',
# ...

# %%
raw_df.rename(columns={"课程号   课程名   ":"姓名"},inplace=True)

# %%
import numpy as np
raw_df.drop(columns=['Unnamed: 87','Unnamed: 88','Unnamed: 89'],inplace=True,axis=1)

# %%
raw_df.head()
# Out:
#                 姓名 ACH1131101          会计学    ECK1131004          宏观经济学       \
# 20160759.0  闫胜奎                      80.0                           77.0
# 20163461.0  时煜翔                      60.0                           70.0
# 20163474.0    王宇                     77.0                           78.0
# 20163486.0  郑冬阳                      63.0                           66.0
# 20163498.0  袁晓萌                      95.0                           92.0
#
#            FAE2221004          中国管理智慧        \
# 20160759.0                         95.0
# 20163461.0                               -
# 20163474.0                               -
# 20163486.0                               -
# 20163498.0                               -
#
#            LSM2221010          美国国家安全战略分析            \
# 20160759.0                                 94.0
# 20163461.0                                       -
# 20163474.0                                       -
# 20163486.0                                       -
# ...

# %%
lst = []
with open("inputData/mustClass.txt","r") as file:
    lines = file.readlines()
for i in lines:
    lst.append(i.strip("\n"))
lst
# Out:
# ['计算机网络基础',
#  '统计学',
#  '会计学',
#  '管理学',
#  '计算机网络基础（实验）',
#  '计算机程序设计（实验）',
#  '计算机程序设计',
#  '财务管理与财务报告分析',
#  '管理信息系统',
#  '管理运筹学',
#  '信息管理学',
#  '概率论与数理统计',
#  '高等数学（下）',
#  '英语精读（下）',
#  '英语听力（下）',
#  '计算机应用基础',
#  '英语听力（上）',
#  '高等数学（上）',
#  '线性代数',
#  '英语精读（上）',
#  '数据库应用']

# %%
lst.append("宏观经济学")
df =raw_df
for i in raw_df.columns[1:]:
    if(re.search("^\d",i.split()[0]) != None):
        df.drop(i,axis=1,inplace=True)
    elif(i.split()[1] in lst):
        df.drop(i,axis=1,inplace=True)
df.columns
# Out:
# Index(['姓名', 'FAE2221004          中国管理智慧      ',
#        'LSM2221010          美国国家安全战略分析          ',
#        'SAL2221003          创业基础与案例分析         ',
#        'ECE2221001          外国经济史     ',
#        'KF0022      Photoshop基础与应用              ', 'KF0066      走遍日本    ',
#        'PTM2221013          网球  ', 'LMD2221011          声乐艺术    ',
#        'LMD2221014          演讲与口才     ', 'PTM2221003          篮球  ',
#        'PTM2221006          乒乓球   ', 'SAB2221011          市场调查    ',
#        'SAL2223004          创新实践活动      ', 'FLM2221013          法语  ',
#        'LMM2221004          言语交际学     ', 'PTM2221009          太极拳   ',
#        'KF0050      全国大学生物流设计大赛辅导             ',
#        'SAL2211001          创新文化    ',
#        'SAL2211003          职业生涯与发展规划         ',
#        'FAM2221002          管理文化    ', 'ITL2223001          企业决策模拟实验        ',
#        'KF0046      网络营销实训      ', 'KF0065      走遍韩国    ',
#        'KF0111      法语日常会话      ', 'LSK2121001          法学通论    ',
# ...

# %%
df1 =
# Out:
#                 姓名 ACH1131101           ECK1131004            \
# 20160759.0  闫胜奎                80.0                 77.0
# 20163461.0  时煜翔                60.0                 70.0
# 20163474.0    王宇               77.0                 78.0
# 20163486.0  郑冬阳                63.0                 66.0
# 20163498.0  袁晓萌                95.0                 92.0
#
#            FAE2221004           LSM2221010           MTH1121303            \
# 20160759.0             95.0                 94.0                 83.0
# 20163461.0                   -                    -              72.0
# 20163474.0                   -                    -              79.0
# 20163486.0                   -                    -              73.0
# 20163498.0                   -                    -              91.0
#
#            MTH1131031           MTH2113303           SAL2221003            \
# 20160759.0             84.0                 91.0                 93.0
# ...

# %%
re.search("123","1") == False
# Out:
# False

# %%
# Out:
# No
